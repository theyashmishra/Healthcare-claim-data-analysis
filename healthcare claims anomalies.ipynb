# %%
import pandas as pd
import matplotlib.pyplot as  plt
from matplotlib import style
style.use('ggplot')
# %matplotlib inline
import plotly
import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as pyo
import cufflinks as cf
from plotly.offline import init_notebook_mode,plot,iplot
import folium

# %%
df=pd.read_csv('Train_Beneficiarydata-1542865627584.csv')

# %%
df
# Out:
#             BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  \
# 0        BENE11001  1943-01-01  NaN       1     1                     0
# 1        BENE11002  1936-09-01  NaN       2     1                     0
# 2        BENE11003  1936-08-01  NaN       1     1                     0
# 3        BENE11004  1922-07-01  NaN       1     1                     0
# 4        BENE11005  1935-09-01  NaN       1     1                     0
# ...            ...         ...  ...     ...   ...                   ...
# 138551  BENE159194  1939-07-01  NaN       1     1                     0
# 138552  BENE159195  1938-12-01  NaN       2     1                     0
# 138553  BENE159196  1916-06-01  NaN       2     1                     0
# 138554  BENE159197  1930-01-01  NaN       1     1                     0
# 138555  BENE159198  1952-04-01  NaN       2     1                     0
#
#         State  County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ...  \
# ...

# %%
f=0;
df2=pd.DataFrame()
df2=df[df['Gender']>2]
df2=df[df['Gender']<1]
if df2.shape[0]!=0:
    print("please correct the discrepencies in gender column",df2)
    f=1

# %%
df2=pd.DataFrame()
df2=df[df['State']>54]
df2=df[df['State']<1]
if df2.shape[0]!=0:
    print("please correct the discrepencies in states column",df2)
    f=1

# %%
df2=pd.DataFrame()
df2=df[df['County']>999]
df2=df[df['County']<0]
if df2.shape[0]!=0:
    print("please correct the discrepencies in Countries column \n",df2)
    f=1;

# %%
df1=pd.read_csv('Train_Inpatientdata-1542865627584.csv')
df1.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt  ... ClmDiagnosisCode_7  ClmDiagnosisCode_8  \
# 0            NaN  2009-04-12  ...               2724               19889
# 1            NaN  2009-08-31  ...                NaN                 NaN
# ...

# %%
df2=pd.DataFrame()
df2=df1[df1['ClaimID'].duplicated()]
if df2.shape[0]!=0:
    print("please correct the discrepencies in Claimid as multiple peoples have same Claimid: \n",df2)
    f=1;

# %%
if(f==0):
    print("No discrepancies found\n")
# Out:
# No discrepancies found

# %%
###data visualization
target=pd.read_csv('Train-1542865627584.csv')

# %%
target.head()
# Out:
#    Provider PotentialFraud
# 0  PRV51001             No
# 1  PRV51003            Yes
# 2  PRV51004             No
# 3  PRV51005            Yes
# 4  PRV51007             No

# %%
from numpy import *
target['bool']=where(target['PotentialFraud']=='No',1,2)

# %%
target.head()
# Out:
#    Provider PotentialFraud  bool
# 0  PRV51001             No     1
# 1  PRV51003            Yes     2
# 2  PRV51004             No     1
# 3  PRV51005            Yes     2
# 4  PRV51007             No     1

# %%
import seaborn as sns
plt.title("Potential Fraud Test distribution")
target.groupby( ["PotentialFraud"] ).Provider.count().plot(kind = "bar", figsize = (10,6))
plt.xlabel('Status')
plt.ylabel('Count')
plt.show()

# %%
df['Provider']=target['Provider']
df["PotentialFraud"]=target["PotentialFraud"]
plt.figure(figsize=(20, 20))
plt.title('Correlation heatmap')
sns.heatmap(df1.corr())
plt.show()

# %%
print("No. of Null values",df.isnull().sum())
# Out:
# No. of Null values BeneID                                  0
# DOB                                     0
# DOD                                137135
# Gender                                  0
# Race                                    0
# RenalDiseaseIndicator                   0
# State                                   0
# County                                  0
# NoOfMonths_PartACov                     0
# NoOfMonths_PartBCov                     0
# ChronicCond_Alzheimer                   0
# ChronicCond_Heartfailure                0
# ChronicCond_KidneyDisease               0
# ChronicCond_Cancer                      0
# ChronicCond_ObstrPulmonary              0
# ChronicCond_Depression                  0
# ChronicCond_Diabetes                    0
# ChronicCond_IschemicHeart               0
# ChronicCond_Osteoporasis                0
# ChronicCond_rheumatoidarthritis         0
# ChronicCond_stroke                      0
# IPAnnualReimbursementAmt                0
# ...
